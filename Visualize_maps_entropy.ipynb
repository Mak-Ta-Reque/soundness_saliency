# %%
import os
import numpy as np
from matplotlib import pyplot as plt
import json

# %%
print(os.listdir("results"))
# Out:
# ['batch_1010.pkl', 'batch_50.pkl', 'batch_1050.pkl', 'batch_20.pkl', 'batch_210.pkl', 'batch_70.pkl', 'batch_170.pkl', 'batch_1060.pkl', 'batch_250.pkl', 'batch_140.pkl', 'batch_1000.pkl', 'batch_1040.pkl', 'batch_220.pkl', 'batch_1090.pkl', 'batch_1020.pkl', 'batch_120.pkl', 'batch_110.pkl', 'batch_260.pkl', 'batch_80.pkl', 'batch_1080.pkl', 'batch_100.pkl', 'batch_150.pkl', 'batch_180.pkl', 'batch_1030.pkl', 'batch_10.pkl', 'batch_60.pkl', 'batch_240.pkl', 'batch_90.pkl', 'batch_270.pkl', 'batch_290.pkl', 'batch_1070.pkl', 'batch_280.pkl', 'batch_40.pkl', 'batch_200.pkl', 'batch_190.pkl', 'batch_230.pkl', 'batch_160.pkl', 'batch_130.pkl', 'batch_0.pkl', 'batch_30.pkl']

# %%
images = np.load('input_data/sample_images.npy', allow_pickle=True)
labels = np.load('input_data/sample_labels.npy', allow_pickle=True)
label_mapper = np.load("imagenet_label_name.npy", allow_pickle=True).item()
batch = 1090

# %%
maps = np.load(f'results/batch_{batch}'+ '.pkl', allow_pickle=True)[('rand_image', 1, 4, 2e-05, 0.01, 0.0)]

# %%
import json
  
# reading the data from the file
with open('labels.txt') as f:
    data = f.read()
  
read_lavels = eval(data)

# %%
fig = plt.figure(figsize = (18,18))
for k in range(1,11,2):
    plt.subplot(5,2,k)
    lbl = maps[1][k-1]
    l = label_mapper[str(labels[batch+k-1])]
    plt.title(f"{read_lavels[maps[1][k-1]]}: p =  {'{:.3f}'.format( maps[2][k-1][maps[1][k-1]])}")
    plt.imshow(maps[0][0][k-1][0])
    plt.subplot(5,2,k+1)
    plt.title(f"gt: {l[1]}")
    plt.imshow(np.transpose(images[batch+k-1], [1,2,0]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
images[np.isin(labels, [532, 667])].shape
# Out:
# (0, 3, 224, 224)

# %%
labels
# Out:
# array([664, 673, 782, 782, 673, 851, 851, 664, 782, 851, 664, 527, 664,
#        782, 851, 782, 526, 673, 664, 673, 673, 782, 527, 526, 526, 851,
#        782, 664, 673, 782, 782, 673, 673, 673, 664, 782, 851, 673, 526,
#        664, 673, 526, 782, 851, 664, 664, 664, 527, 664, 851, 673, 673,
#        527, 673, 664, 782, 673, 851, 526, 851, 527, 664, 526, 673, 526,
#        782, 782, 526, 782, 526, 851, 673, 526, 664, 851, 664, 526, 527,
#        526, 782, 527, 664, 851, 664, 527, 664, 664, 851, 851, 851, 527,
#        851, 526, 782, 526, 782, 673, 527, 664, 527, 851, 782])

# %%
len(images)
# Out:
# 102

# %%
plt.imshow(np.transpose(images[4], [1,2,0]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
np.unique(labels)
# Out:
# array([526, 527, 664, 673, 782, 851])
